# %%
# Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# creat a se of random latitude and longitudes combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
#import citpy 
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# ipor dependencies and URL
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities. city weahter is a lsit of dic need [0]
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weath = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Des": city_weath,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sitka
# Processing Record 2 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | dingle
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | qianan
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | salalah
# Processing Record 12 of Set 1 | lasa
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | east london
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | kodinsk
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | biak
# Processing Record 20 of Set 1 | nikki
# Processing Record 21 of Set 1 | kulhudhuffushi
# Processing Record 22 of Set 1 | karratha
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | azogues
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | qaanaaq
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | merauke
# Processing Record 30 of Set 1 | yakeshi
# Processing Record 31 of Set 1 | rabo de peixe
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | sechura
# Processing Record 35 of Set 1 | cascavel
# Processing Record 36 of Set 1 | goderich
# Processing Record 37 of Set 1 | senanga
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | lazurne
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | temnikov
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | nouakchott
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 1 | clyde river
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | ushuaia
# Processing Record 3 of Set 2 | narsaq
# Processing Record 4 of Set 2 | upernavik
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | chegdomyn
# Processing Record 7 of Set 2 | oranjemund
# Processing Record 8 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | madison
# Processing Record 12 of Set 2 | san fernando
# Processing Record 13 of Set 2 | jarva-jaani
# Processing Record 14 of Set 2 | grindavik
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | pangai
# Processing Record 17 of Set 2 | port-gentil
# Processing Record 18 of Set 2 | nelspruit
# Processing Record 19 of Set 2 | makakilo city
# Processing Record 20 of Set 2 | kutum
# Processing Record 21 of Set 2 | moree
# Processing Record 22 of Set 2 | filadelfia
# Processing Record 23 of Set 2 | baturaja
# Processing Record 24 of Set 2 | bengkulu
# Processing Record 25 of Set 2 | coahuayana
# Processing Record 26 of Set 2 | yellowknife
# Processing Record 27 of Set 2 | san andres
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | lebu
# Processing Record 30 of Set 2 | havre-saint-pierre
# Processing Record 31 of Set 2 | tadine
# Processing Record 32 of Set 2 | wajid
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | nemuro
# Processing Record 42 of Set 2 | upington
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | roald
# Processing Record 45 of Set 2 | comodoro rivadavia
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | port-cartier
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | norman wells
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | piacabucu
# Processing Record 2 of Set 3 | faya
# Processing Record 3 of Set 3 | aasiaat
# Processing Record 4 of Set 3 | bambous virieux
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | slave lake
# Processing Record 7 of Set 3 | mauguio
# Processing Record 8 of Set 3 | galle
# Processing Record 9 of Set 3 | coruripe
# Processing Record 10 of Set 3 | waipawa
# Processing Record 11 of Set 3 | nishihara
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | la asuncion
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | talnakh
# Processing Record 19 of Set 3 | vestmannaeyjar
# Processing Record 20 of Set 3 | hermanus
# Processing Record 21 of Set 3 | yulara
# Processing Record 22 of Set 3 | zyryanka
# Processing Record 23 of Set 3 | saint-augustin
# Processing Record 24 of Set 3 | svetlogorsk
# Processing Record 25 of Set 3 | rognan
# Processing Record 26 of Set 3 | zachepylivka
# Processing Record 27 of Set 3 | linhares
# Processing Record 28 of Set 3 | camacha
# Processing Record 29 of Set 3 | cap malheureux
# Processing Record 30 of Set 3 | lagoa
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | gamba
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | cape coast
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | gurskoye
# City not found. Skipping...
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | kavieng
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | portland
# Processing Record 44 of Set 3 | shenkursk
# Processing Record 45 of Set 3 | san patricio
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | praia
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | tautira
# Processing Record 2 of Set 4 | luba
# Processing Record 3 of Set 4 | ranong
# Processing Record 4 of Set 4 | staryy nadym
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | sandpoint
# Processing Record 7 of Set 4 | tiarei
# Processing Record 8 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 4 | otane
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | shimanovsk
# Processing Record 12 of Set 4 | zhezkazgan
# Processing Record 13 of Set 4 | baykit
# Processing Record 14 of Set 4 | abaza
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | casas grandes
# Processing Record 17 of Set 4 | despotovac
# Processing Record 18 of Set 4 | carmarthen
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | thompson
# Processing Record 22 of Set 4 | inuvik
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | alyangula
# Processing Record 25 of Set 4 | cape town
# Processing Record 26 of Set 4 | el sauzal
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | margosatubig
# Processing Record 29 of Set 4 | millington
# Processing Record 30 of Set 4 | katobu
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | karaton
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | ribas do rio pardo
# Processing Record 35 of Set 4 | ondjiva
# Processing Record 36 of Set 4 | kruisfontein
# Processing Record 37 of Set 4 | kirakira
# Processing Record 38 of Set 4 | pecos
# Processing Record 39 of Set 4 | mount isa
# Processing Record 40 of Set 4 | bud
# Processing Record 41 of Set 4 | praia da vitoria
# Processing Record 42 of Set 4 | castro
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 4 | teguldet
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | charters towers
# Processing Record 48 of Set 4 | tasiilaq
# Processing Record 49 of Set 4 | sambava
# Processing Record 50 of Set 4 | pochutla
# Processing Record 1 of Set 5 | padang
# Processing Record 2 of Set 5 | boksitogorsk
# Processing Record 3 of Set 5 | saiha
# Processing Record 4 of Set 5 | inongo
# Processing Record 5 of Set 5 | suntar
# Processing Record 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5 | pulandian
# Processing Record 8 of Set 5 | mastic beach
# Processing Record 9 of Set 5 | riyadh
# Processing Record 10 of Set 5 | tarrafal
# Processing Record 11 of Set 5 | mar del plata
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | adrar
# Processing Record 14 of Set 5 | asau
# Processing Record 15 of Set 5 | tabou
# Processing Record 16 of Set 5 | khuzhir
# Processing Record 17 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 18 of Set 5 | yekaterinovka
# Processing Record 19 of Set 5 | los llanos de aridane
# Processing Record 20 of Set 5 | yarim
# Processing Record 21 of Set 5 | north marysville
# City not found. Skipping...
# Processing Record 22 of Set 5 | lata
# Processing Record 23 of Set 5 | duz
# City not found. Skipping...
# Processing Record 24 of Set 5 | yazman
# Processing Record 25 of Set 5 | kavaratti
# Processing Record 26 of Set 5 | houma
# Processing Record 27 of Set 5 | cockburn town
# Processing Record 28 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 5 | bukama
# Processing Record 30 of Set 5 | sakakah
# Processing Record 31 of Set 5 | montelibano
# Processing Record 32 of Set 5 | noumea
# Processing Record 33 of Set 5 | hasaki
# Processing Record 34 of Set 5 | broome
# Processing Record 35 of Set 5 | leshukonskoye
# Processing Record 36 of Set 5 | troitsko-pechorsk
# Processing Record 37 of Set 5 | akyab
# Processing Record 38 of Set 5 | soe
# Processing Record 39 of Set 5 | bandarbeyla
# Processing Record 40 of Set 5 | mazatlan
# Processing Record 41 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 5 | kununurra
# Processing Record 43 of Set 5 | mutsu
# Processing Record 44 of Set 5 | torbay
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | paka
# Processing Record 47 of Set 5 | yaan
# Processing Record 48 of Set 5 | kralendijk
# Processing Record 49 of Set 5 | mildura
# Processing Record 50 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 6 | nanortalik
# Processing Record 2 of Set 6 | jumla
# Processing Record 3 of Set 6 | saint-pierre
# Processing Record 4 of Set 6 | gayny
# Processing Record 5 of Set 6 | tuktoyaktuk
# Processing Record 6 of Set 6 | hokitika
# Processing Record 7 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 8 of Set 6 | semey
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | luorong
# Processing Record 11 of Set 6 | zhangye
# Processing Record 12 of Set 6 | gat
# Processing Record 13 of Set 6 | van
# Processing Record 14 of Set 6 | loubomo
# Processing Record 15 of Set 6 | sedelnikovo
# City not found. Skipping...
# Processing Record 16 of Set 6 | perelyub
# Processing Record 17 of Set 6 | teluk nibung
# Processing Record 18 of Set 6 | lumberton
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | college
# Processing Record 21 of Set 6 | olafsvik
# Processing Record 22 of Set 6 | dunedin
# Processing Record 23 of Set 6 | vila
# Processing Record 24 of Set 6 | half moon bay
# Processing Record 25 of Set 6 | umm lajj
# Processing Record 26 of Set 6 | nong phai
# Processing Record 27 of Set 6 | viedma
# Processing Record 28 of Set 6 | demba
# Processing Record 29 of Set 6 | aguas verdes
# Processing Record 30 of Set 6 | tessalit
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | margate
# Processing Record 33 of Set 6 | tehuixtla
# Processing Record 34 of Set 6 | tomatlan
# Processing Record 35 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 6 | gujrat
# Processing Record 37 of Set 6 | saskylakh
# Processing Record 38 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 6 | yavatmal
# Processing Record 40 of Set 6 | ambilobe
# Processing Record 41 of Set 6 | dabat
# Processing Record 42 of Set 6 | traverse city
# Processing Record 43 of Set 6 | arica
# Processing Record 44 of Set 6 | nicoya
# Processing Record 45 of Set 6 | brae
# Processing Record 46 of Set 6 | birobidzhan
# Processing Record 47 of Set 6 | dukat
# Processing Record 48 of Set 6 | broken hill
# Processing Record 49 of Set 6 | bagdarin
# Processing Record 50 of Set 6 | itoman
# Processing Record 1 of Set 7 | tazovskiy
# Processing Record 2 of Set 7 | senador guiomard
# Processing Record 3 of Set 7 | chiriqui grande
# Processing Record 4 of Set 7 | vostok
# Processing Record 5 of Set 7 | belmonte
# Processing Record 6 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 7 | oktyabrskiy
# Processing Record 8 of Set 7 | aranos
# Processing Record 9 of Set 7 | zhangjiakou
# Processing Record 10 of Set 7 | khandbari
# Processing Record 11 of Set 7 | pasighat
# Processing Record 12 of Set 7 | lumphat
# Processing Record 13 of Set 7 | bayanday
# Processing Record 14 of Set 7 | sungairaya
# Processing Record 15 of Set 7 | mehamn
# Processing Record 16 of Set 7 | ikalamavony
# Processing Record 17 of Set 7 | gravdal
# Processing Record 18 of Set 7 | sukhumi
# Processing Record 19 of Set 7 | coos bay
# Processing Record 20 of Set 7 | seddon
# Processing Record 21 of Set 7 | parrita
# Processing Record 22 of Set 7 | maldonado
# Processing Record 23 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 7 | sabha
# Processing Record 25 of Set 7 | lensk
# Processing Record 26 of Set 7 | takaka
# Processing Record 27 of Set 7 | sonoita
# Processing Record 28 of Set 7 | mizdah
# Processing Record 29 of Set 7 | mujiayingzi
# Processing Record 30 of Set 7 | lompoc
# Processing Record 31 of Set 7 | arkhangelsk
# Processing Record 32 of Set 7 | souillac
# Processing Record 33 of Set 7 | koygorodok
# Processing Record 34 of Set 7 | winnemucca
# Processing Record 35 of Set 7 | canon city
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | ayan
# Processing Record 38 of Set 7 | cairns
# Processing Record 39 of Set 7 | cherskiy
# Processing Record 40 of Set 7 | luanda
# Processing Record 41 of Set 7 | abu samrah
# Processing Record 42 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 43 of Set 7 | dumas
# Processing Record 44 of Set 7 | mitsamiouli
# Processing Record 45 of Set 7 | honiara
# Processing Record 46 of Set 7 | cayenne
# Processing Record 47 of Set 7 | ishigaki
# Processing Record 48 of Set 7 | tuatapere
# Processing Record 49 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 7 | buraydah
# Processing Record 1 of Set 8 | cidreira
# Processing Record 2 of Set 8 | varhaug
# Processing Record 3 of Set 8 | buariki
# City not found. Skipping...
# Processing Record 4 of Set 8 | kangalassy
# Processing Record 5 of Set 8 | beringovskiy
# Processing Record 6 of Set 8 | sindand
# City not found. Skipping...
# Processing Record 7 of Set 8 | cabo san lucas
# Processing Record 8 of Set 8 | srednekolymsk
# Processing Record 9 of Set 8 | mazara del vallo
# Processing Record 10 of Set 8 | port blair
# Processing Record 11 of Set 8 | riachao das neves
# Processing Record 12 of Set 8 | nizwa
# Processing Record 13 of Set 8 | kosh-agach
# Processing Record 14 of Set 8 | banda aceh
# Processing Record 15 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 16 of Set 8 | custodia
# Processing Record 17 of Set 8 | ust-omchug
# Processing Record 18 of Set 8 | dakar
# Processing Record 19 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 8 | high rock
# Processing Record 21 of Set 8 | mahon
# Processing Record 22 of Set 8 | natchitoches
# Processing Record 23 of Set 8 | karasjok
# Processing Record 24 of Set 8 | bubaque
# Processing Record 25 of Set 8 | ponta delgada
# Processing Record 26 of Set 8 | alice springs
# Processing Record 27 of Set 8 | airai
# Processing Record 28 of Set 8 | touho
# Processing Record 29 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 30 of Set 8 | ilulissat
# Processing Record 31 of Set 8 | urengoy
# Processing Record 32 of Set 8 | shetpe
# Processing Record 33 of Set 8 | egvekinot
# Processing Record 34 of Set 8 | collie
# Processing Record 35 of Set 8 | acarau
# Processing Record 36 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 8 | ninotsminda
# Processing Record 38 of Set 8 | sault sainte marie
# Processing Record 39 of Set 8 | tutoia
# Processing Record 40 of Set 8 | vyshkov
# Processing Record 41 of Set 8 | gainesville
# Processing Record 42 of Set 8 | bereda
# Processing Record 43 of Set 8 | rio branco do sul
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 46 of Set 8 | aswan
# Processing Record 47 of Set 8 | takoradi
# Processing Record 48 of Set 8 | norrtalje
# Processing Record 49 of Set 8 | kidal
# Processing Record 50 of Set 8 | deputatskiy
# Processing Record 1 of Set 9 | ust-tarka
# Processing Record 2 of Set 9 | skibbereen
# Processing Record 3 of Set 9 | ariquemes
# Processing Record 4 of Set 9 | kez
# Processing Record 5 of Set 9 | ojinaga
# Processing Record 6 of Set 9 | linxia
# Processing Record 7 of Set 9 | pevek
# Processing Record 8 of Set 9 | ebreichsdorf
# Processing Record 9 of Set 9 | kuminskiy
# Processing Record 10 of Set 9 | remanso
# Processing Record 11 of Set 9 | bonavista
# Processing Record 12 of Set 9 | dubai
# Processing Record 13 of Set 9 | alugan
# Processing Record 14 of Set 9 | awjilah
# Processing Record 15 of Set 9 | sarangani
# Processing Record 16 of Set 9 | ixtapa
# Processing Record 17 of Set 9 | mogadishu
# Processing Record 18 of Set 9 | hakodate
# Processing Record 19 of Set 9 | beaucaire
# Processing Record 20 of Set 9 | la ronge
# Processing Record 21 of Set 9 | lagunas
# Processing Record 22 of Set 9 | touros
# Processing Record 23 of Set 9 | north bend
# Processing Record 24 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 25 of Set 9 | hovd
# Processing Record 26 of Set 9 | coquimbo
# Processing Record 27 of Set 9 | paita
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 9 | bhum
# Processing Record 31 of Set 9 | moura
# Processing Record 32 of Set 9 | den helder
# Processing Record 33 of Set 9 | terrace
# Processing Record 34 of Set 9 | mahebourg
# Processing Record 35 of Set 9 | arecibo
# Processing Record 36 of Set 9 | buchanan
# Processing Record 37 of Set 9 | krivosheino
# Processing Record 38 of Set 9 | westport
# Processing Record 39 of Set 9 | codrington
# Processing Record 40 of Set 9 | tura
# Processing Record 41 of Set 9 | agadez
# Processing Record 42 of Set 9 | russell
# Processing Record 43 of Set 9 | saint-georges
# Processing Record 44 of Set 9 | warrensburg
# Processing Record 45 of Set 9 | chapais
# Processing Record 46 of Set 9 | walvis bay
# Processing Record 47 of Set 9 | cavalcante
# Processing Record 48 of Set 9 | paragominas
# Processing Record 49 of Set 9 | kjopsvik
# Processing Record 50 of Set 9 | storm lake
# Processing Record 1 of Set 10 | nara
# Processing Record 2 of Set 10 | zhigansk
# Processing Record 3 of Set 10 | huilong
# Processing Record 4 of Set 10 | san carlos de bariloche
# Processing Record 5 of Set 10 | chuy
# Processing Record 6 of Set 10 | pryamitsyno
# Processing Record 7 of Set 10 | scarborough
# Processing Record 8 of Set 10 | odesskoye
# Processing Record 9 of Set 10 | okhotsk
# Processing Record 10 of Set 10 | penzance
# Processing Record 11 of Set 10 | xiuyan
# Processing Record 12 of Set 10 | evensk
# Processing Record 13 of Set 10 | lundazi
# Processing Record 14 of Set 10 | byron bay
# Processing Record 15 of Set 10 | masty
# Processing Record 16 of Set 10 | yuxia
# Processing Record 17 of Set 10 | pierre
# Processing Record 18 of Set 10 | imeni poliny osipenko
# Processing Record 19 of Set 10 | kaitangata
# Processing Record 20 of Set 10 | prainha
# Processing Record 21 of Set 10 | sorland
# Processing Record 22 of Set 10 | iberia
# Processing Record 23 of Set 10 | qaqortoq
# Processing Record 24 of Set 10 | cochabamba
# Processing Record 25 of Set 10 | slantsy
# Processing Record 26 of Set 10 | orlik
# Processing Record 27 of Set 10 | yamoussoukro
# Processing Record 28 of Set 10 | caconde
# Processing Record 29 of Set 10 | tocopilla
# Processing Record 30 of Set 10 | bolobo
# Processing Record 31 of Set 10 | manzanillo
# Processing Record 32 of Set 10 | rocha
# Processing Record 33 of Set 10 | hobyo
# Processing Record 34 of Set 10 | xichang
# Processing Record 35 of Set 10 | hambantota
# Processing Record 36 of Set 10 | marawi
# Processing Record 37 of Set 10 | fairbanks
# Processing Record 38 of Set 10 | mwense
# Processing Record 39 of Set 10 | rawson
# Processing Record 40 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 41 of Set 10 | jalu
# Processing Record 42 of Set 10 | chemal
# Processing Record 43 of Set 10 | conceicao do araguaia
# Processing Record 44 of Set 10 | noyabrsk
# Processing Record 45 of Set 10 | kathmandu
# Processing Record 46 of Set 10 | rincon
# Processing Record 47 of Set 10 | ust-karsk
# Processing Record 48 of Set 10 | nhulunbuy
# Processing Record 49 of Set 10 | yambio
# Processing Record 50 of Set 10 | bilma
# Processing Record 1 of Set 11 | kropotkin
# Processing Record 2 of Set 11 | chumikan
# Processing Record 3 of Set 11 | aksarka
# Processing Record 4 of Set 11 | santa fe
# Processing Record 5 of Set 11 | banswara
# Processing Record 6 of Set 11 | shakhtne
# Processing Record 7 of Set 11 | alofi
# Processing Record 8 of Set 11 | nha trang
# Processing Record 9 of Set 11 | gwanda
# Processing Record 10 of Set 11 | boromo
# Processing Record 11 of Set 11 | rantepao
# Processing Record 12 of Set 11 | kichmengskiy gorodok
# Processing Record 13 of Set 11 | balkanabat
# Processing Record 14 of Set 11 | vanavara
# Processing Record 15 of Set 11 | yar-sale
# Processing Record 16 of Set 11 | henties bay
# Processing Record 17 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 11 | bella union
# Processing Record 19 of Set 11 | nongpoh
# Processing Record 20 of Set 11 | skjervoy
# Processing Record 21 of Set 11 | boende
# Processing Record 22 of Set 11 | denpasar
# Processing Record 23 of Set 11 | anopino
# Processing Record 24 of Set 11 | dondo
# Processing Record 25 of Set 11 | kapit
# Processing Record 26 of Set 11 | balykshi
# Processing Record 27 of Set 11 | khani
# Processing Record 28 of Set 11 | constitucion
# Processing Record 29 of Set 11 | burnie
# Processing Record 30 of Set 11 | neuquen
# Processing Record 31 of Set 11 | berlevag
# Processing Record 32 of Set 11 | podgorenskiy
# Processing Record 33 of Set 11 | katangli
# Processing Record 34 of Set 11 | patacamaya
# Processing Record 35 of Set 11 | amapa
# Processing Record 36 of Set 11 | katsuura
# Processing Record 37 of Set 11 | arman
# Processing Record 38 of Set 11 | port augusta
# Processing Record 39 of Set 11 | magadan
# Processing Record 40 of Set 11 | olinda
# Processing Record 41 of Set 11 | ornskoldsvik
# Processing Record 42 of Set 11 | conceicao do mato dentro
# Processing Record 43 of Set 11 | shimoda
# Processing Record 44 of Set 11 | tarko-sale
# Processing Record 45 of Set 11 | wum
# Processing Record 46 of Set 11 | lichuan
# Processing Record 47 of Set 11 | feicheng
# Processing Record 48 of Set 11 | novotroitsk
# Processing Record 49 of Set 11 | vao
# Processing Record 50 of Set 11 | umm kaddadah
# Processing Record 1 of Set 12 | turayf
# Processing Record 2 of Set 12 | dosso
# Processing Record 3 of Set 12 | dauriya
# Processing Record 4 of Set 12 | boguchany
# Processing Record 5 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 6 of Set 12 | marsh harbour
# Processing Record 7 of Set 12 | miramar
# Processing Record 8 of Set 12 | fukue
# Processing Record 9 of Set 12 | preobrazheniye
# Processing Record 10 of Set 12 | monduli
# Processing Record 11 of Set 12 | meulaboh
# Processing Record 12 of Set 12 | khuzdar
# Processing Record 13 of Set 12 | constancia
# Processing Record 14 of Set 12 | inta
# Processing Record 15 of Set 12 | corinth
# Processing Record 16 of Set 12 | birao
# Processing Record 17 of Set 12 | longonjo
# Processing Record 18 of Set 12 | fria
# Processing Record 19 of Set 12 | auki
# Processing Record 20 of Set 12 | khorixas
# Processing Record 21 of Set 12 | sal rei
# Processing Record 22 of Set 12 | trinidad
# Processing Record 23 of Set 12 | taitung
# Processing Record 24 of Set 12 | hirtshals
# Processing Record 25 of Set 12 | necochea
# Processing Record 26 of Set 12 | sur
# Processing Record 27 of Set 12 | mumford
# Processing Record 28 of Set 12 | pimampiro
# Processing Record 29 of Set 12 | trincomalee
# Processing Record 30 of Set 12 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 31 of Set 12 | aykhal
# Processing Record 32 of Set 12 | aksha
# Processing Record 33 of Set 12 | mackay
# Processing Record 34 of Set 12 | maniitsoq
# Processing Record 35 of Set 12 | bathsheba
# Processing Record 36 of Set 12 | san pedro
# Processing Record 37 of Set 12 | upata
# Processing Record 38 of Set 12 | abha
# Processing Record 39 of Set 12 | esmeraldas
# Processing Record 40 of Set 12 | burns lake
# Processing Record 41 of Set 12 | ankang
# Processing Record 42 of Set 12 | tongzi
# Processing Record 43 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 12 | palatka
# Processing Record 45 of Set 12 | lusambo
# Processing Record 46 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 12 | atambua
# Processing Record 48 of Set 12 | daru
# Processing Record 49 of Set 12 | segezha
# Processing Record 50 of Set 12 | nkowakowa
# Processing Record 1 of Set 13 | punta cardon
# Processing Record 2 of Set 13 | la brea
# Processing Record 3 of Set 13 | funabashi
# Processing Record 4 of Set 13 | san quintin
# Processing Record 5 of Set 13 | pedra azul
# Processing Record 6 of Set 13 | masuguru
# Processing Record 7 of Set 13 | arrecife
# Processing Record 8 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 13 | nortelandia
# Processing Record 10 of Set 13 | grand gaube
# Processing Record 11 of Set 13 | chipinge
# Processing Record 12 of Set 13 | sanok
# Processing Record 13 of Set 13 | zhanjiang
# Processing Record 14 of Set 13 | sola
# Processing Record 15 of Set 13 | doha
# Processing Record 16 of Set 13 | san angelo
# Processing Record 17 of Set 13 | fortuna
# Processing Record 18 of Set 13 | sibolga
# Processing Record 19 of Set 13 | yarada
# Processing Record 20 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 13 | namibe
# Processing Record 22 of Set 13 | fushan
# Processing Record 23 of Set 13 | port lincoln
# Processing Record 24 of Set 13 | kawasaki
# Processing Record 25 of Set 13 | vyshestebliyevskaya
# Processing Record 26 of Set 13 | san policarpo
# Processing Record 27 of Set 13 | carhuamayo
# Processing Record 28 of Set 13 | tabuk
# Processing Record 29 of Set 13 | prince rupert
# Processing Record 30 of Set 13 | mitu
# Processing Record 31 of Set 13 | safaga
# Processing Record 32 of Set 13 | sao jose da coroa grande
# Processing Record 33 of Set 13 | hay river
# Processing Record 34 of Set 13 | rudsar
# Processing Record 35 of Set 13 | ola
# Processing Record 36 of Set 13 | caetite
# Processing Record 37 of Set 13 | batagay-alyta
# Processing Record 38 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 39 of Set 13 | vila velha
# Processing Record 40 of Set 13 | telimele
# Processing Record 41 of Set 13 | wasilla
# Processing Record 42 of Set 13 | kalofer
# Processing Record 43 of Set 13 | ngunguru
# Processing Record 44 of Set 13 | abu kamal
# Processing Record 45 of Set 13 | leningradskiy
# Processing Record 46 of Set 13 | caucaia
# Processing Record 47 of Set 13 | ifakara
# Processing Record 48 of Set 13 | mercedes
# Processing Record 49 of Set 13 | ushtobe
# Processing Record 50 of Set 13 | guerrero negro
# Processing Record 1 of Set 14 | kawalu
# Processing Record 2 of Set 14 | metkovic
# Processing Record 3 of Set 14 | isugod
# Processing Record 4 of Set 14 | antonovo
# Processing Record 5 of Set 14 | casper
# Processing Record 6 of Set 14 | verkhoyansk
# Processing Record 7 of Set 14 | oranjestad
# Processing Record 8 of Set 14 | cuamba
# Processing Record 9 of Set 14 | beloha
# Processing Record 10 of Set 14 | moose factory
# Processing Record 11 of Set 14 | seoul
# Processing Record 12 of Set 14 | lakatoro
# Processing Record 13 of Set 14 | willowmore
# Processing Record 14 of Set 14 | najran
# Processing Record 15 of Set 14 | nyurba
# Processing Record 16 of Set 14 | bela
# Processing Record 17 of Set 14 | togur
# Processing Record 18 of Set 14 | ko samui
# Processing Record 19 of Set 14 | majene
# Processing Record 20 of Set 14 | barth
# Processing Record 21 of Set 14 | san clemente
# Processing Record 22 of Set 14 | pacific grove
# Processing Record 23 of Set 14 | anadyr
# Processing Record 24 of Set 14 | mumbwa
# Processing Record 25 of Set 14 | otjimbingwe
# Processing Record 26 of Set 14 | auxerre
# Processing Record 27 of Set 14 | juegang
# Processing Record 28 of Set 14 | port pirie
# Processing Record 29 of Set 14 | sinnamary
# Processing Record 30 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 31 of Set 14 | laramie
# Processing Record 32 of Set 14 | khandyga
# Processing Record 33 of Set 14 | conceicao das alagoas
# Processing Record 34 of Set 14 | balakhninskiy
# Processing Record 35 of Set 14 | ailigandi
# Processing Record 36 of Set 14 | aksu
# Processing Record 37 of Set 14 | raudeberg
# Processing Record 38 of Set 14 | kirkcudbright
# Processing Record 39 of Set 14 | pietarsaari
# Processing Record 40 of Set 14 | melnikovo
# Processing Record 41 of Set 14 | shingu
# Processing Record 42 of Set 14 | binzhou
# Processing Record 43 of Set 14 | aksay
# Processing Record 44 of Set 14 | tighina
# Processing Record 45 of Set 14 | opuwo
# Processing Record 46 of Set 14 | kisangani
# Processing Record 47 of Set 14 | ocampo
# Processing Record 48 of Set 14 | port macquarie
# Processing Record 49 of Set 14 | tagusao
# Processing Record 50 of Set 14 | lavrentiya
# Processing Record 1 of Set 15 | paoua
# Processing Record 2 of Set 15 | hillsboro
# Processing Record 3 of Set 15 | empangeni
# Processing Record 4 of Set 15 | simao
# Processing Record 5 of Set 15 | hudson bay
# Processing Record 6 of Set 15 | palmas
# Processing Record 7 of Set 15 | beyneu
# Processing Record 8 of Set 15 | show low
# Processing Record 9 of Set 15 | apatin
# Processing Record 10 of Set 15 | caravelas
# Processing Record 11 of Set 15 | adre
# Processing Record 12 of Set 15 | novyy urengoy
# Processing Record 13 of Set 15 | chanika
# Processing Record 14 of Set 15 | halifax
# Processing Record 15 of Set 15 | zanesville
# Processing Record 16 of Set 15 | kenai
# Processing Record 17 of Set 15 | labuhan
# Processing Record 18 of Set 15 | khromtau
# Processing Record 19 of Set 15 | huimanguillo
# Processing Record 20 of Set 15 | plettenberg bay
# Processing Record 21 of Set 15 | mareeba
# Processing Record 22 of Set 15 | marzuq
# Processing Record 23 of Set 15 | waqqas
# Processing Record 24 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 25 of Set 15 | damghan
# Processing Record 26 of Set 15 | marienberg
# Processing Record 27 of Set 15 | carovigno
# Processing Record 28 of Set 15 | coolum beach
# Processing Record 29 of Set 15 | batemans bay
# Processing Record 30 of Set 15 | soller
# Processing Record 31 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 32 of Set 15 | beira
# Processing Record 33 of Set 15 | juli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Sitka  57.0531 -135.3300     35.60        75          20
# 1       Sao Filipe  14.8961  -24.4956     69.91        74           3
# 2  Arraial Do Cabo -22.9661  -42.0278     89.60        74          20
# 3           Dingle  10.9995  122.6711     76.86        86          80
# 4           Albany  42.6001  -73.9662     50.00        85         100
# 5           Qianan  44.9932  124.0581     42.91        50           7
# 6   Ribeira Grande  38.5167  -28.7000     62.60        72          40
# 7        Busselton -33.6500  115.3333     60.01        91           0
# 8        Ostrovnoy  68.0531   39.5131     35.28        98         100
# 9          Salalah  17.0151   54.0924     84.20        61           0
#
#    Wind Speed       Weather Des Country                 Date
# 0       10.36        few clouds      US  2021-03-28 16:07:31
# 1       15.12         clear sky      CV  2021-03-28 16:09:17
# 2       12.66        few clouds      BR  2021-03-28 16:09:17
# 3        5.95     broken clouds      PH  2021-03-28 16:09:18
# 4       13.73     moderate rain      US  2021-03-28 16:07:35
# 5       15.50         clear sky      CN  2021-03-28 16:09:18
# 6       13.80  scattered clouds      PT  2021-03-28 16:09:18
# 7        8.43         clear sky      AU  2021-03-28 16:09:18
# 8       17.05   overcast clouds      RU  2021-03-28 16:09:19
# 9        2.30         clear sky      OM  2021-03-28 16:09:19

# %%
# re-orderthe data fram columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Des", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Sitka      US  57.0531 -135.3300     35.60        75          20
# 1       Sao Filipe      CV  14.8961  -24.4956     69.91        74           3
# 2  Arraial Do Cabo      BR -22.9661  -42.0278     89.60        74          20
# 3           Dingle      PH  10.9995  122.6711     76.86        86          80
# 4           Albany      US  42.6001  -73.9662     50.00        85         100
# 5           Qianan      CN  44.9932  124.0581     42.91        50           7
# 6   Ribeira Grande      PT  38.5167  -28.7000     62.60        72          40
# 7        Busselton      AU -33.6500  115.3333     60.01        91           0
# 8        Ostrovnoy      RU  68.0531   39.5131     35.28        98         100
# 9          Salalah      OM  17.0151   54.0924     84.20        61           0
#
#    Wind Speed       Weather Des                 Date
# 0       10.36        few clouds  2021-03-28 16:07:31
# 1       15.12         clear sky  2021-03-28 16:09:17
# 2       12.66        few clouds  2021-03-28 16:09:17
# 3        5.95     broken clouds  2021-03-28 16:09:18
# 4       13.73     moderate rain  2021-03-28 16:07:35
# 5       15.50         clear sky  2021-03-28 16:09:18
# 6       13.80  scattered clouds  2021-03-28 16:09:18
# 7        8.43         clear sky  2021-03-28 16:09:18
# 8       17.05   overcast clouds  2021-03-28 16:09:19
# 9        2.30         clear sky  2021-03-28 16:09:19

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
